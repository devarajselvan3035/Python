# %% [markdown]
# ## Reverse String using Recursion
# ip = hello world\
# op = dlrow olleh

# %%
def reverse(string: str) -> str:
    if len(string) == 1:
        return string[0]
    return reverse(string[1:]) + string[0]


# print(reverse("hello world"))

# %% [markdown]
# ## check Palindrome using Recursion
# Check given ip and reverced ip both are same
#
# ip = kayak\
# op = True

# %%
def Palindrome(string: str) -> bool:
    if len(string) == 1 or len(string) == 0:
        return True
    if string[0] == string[-1]:
        return Palindrome(string[1:-1])
    return False


# print(Palindrome("raccar"))

# %% [markdown]
# ## Decimal to Binary
# ip = 233\
# op = 11101001

# %%
def decimalTobinary(dec: int) -> str:
    if dec <= 1:
        return str(dec)
    return decimalTobinary(dec // 2) + str(dec % 2)


print(decimalTobinary(233))
# Out:
# 11101001

# %% [markdown]
# ## Sum of Natural Numbers
#
# ip = 5\
# op = (1+2+3+4+5) =15

# %%
def sumOfNaturalnum(num:int) -> int:
    if num == 1:
        return 1
    return num + sumOfNaturalnum(num-1)
print(sumOfNaturalnum(5))
# Out:
# 15

# %% [markdown]
# ## Binary Search

# %%
def binarySearch(arr:list, x:int) -> bool:
    if len(arr) == 0:
        return False
    if len(arr) == 1:
        return True if arr[0] == x else False
    print(arr)
    mid = len(arr) // 2
    print(mid)
    if x == arr[mid]:
        return True
    elif x < arr[mid]:
        return binarySearch(arr[:mid], x)
    else:
        return binarySearch(arr[mid+1:], x)
    return False
print(binarySearch([1,2,3,4,5,6], 10))
# Out:
# [1, 2, 3, 4, 5, 6]
# 3
# [5, 6]
# 1
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 14
#      12         return binarySearch(arr[mid+1:], x)
#      13     return False
# ---> 14 print(binarySearch([1,2,3,4,5,6], 10))
#
# Cell In[7], line 12, in binarySearch(arr, x)
#      10     return binarySearch(arr[:mid], x)
#      11 else:
# ---> 12     return binarySearch(arr[mid+1:], x)
#      13 return False
#
# Cell In[7], line 12, in binarySearch(arr, x)
#      10     return binarySearch(arr[:mid], x)
#      11 else:
# ---> 12     return binarySearch(arr[mid+1:], x)
#      13 return False
#
# Cell In[7], line 3, in binarySearch(arr, x)
#       1 def binarySearch(arr:list, x:int) -> bool:
#       2     if len(arr) <= 1:
# ----> 3         return True if arr[0] == x else False
#       4     print(arr)
#       5     mid = len(arr) // 2
#
# IndexError: list index out of range
